# %%
import FinanceDataReader as fdr

# %% [markdown]
# ### 증시 데이터 수집

# %% [markdown]
# #### 주식 데이터

# %%
KP_stock_list = fdr.StockListing("KOSPI") # 코스피 종목 목록
display(KP_stock_list)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_42236\2788067548.py in <module>
# ----> 1 KP_stock_list = fdr.StockListing("KOSPI") # 코스피 종목 목록
#       2 display(KP_stock_list)
#
# ~\AppData\Roaming\Python\Python39\site-packages\FinanceDataReader\data.py in StockListing(market, start, end)
#     156     market = market.upper()
#     157     if market in ['KRX', 'KOSPI', 'KOSDAQ', 'KONEX', 'KRX-MARCAP']:
# --> 158         return KrxMarcapListing(market).read()
#     159     elif market in ['KRX-DESC', 'KOSPI-DESC', 'KOSDAQ-DESC', 'KONEX-DESC']:
#     160         return KrxStockListing(market).read()
#
# ~\AppData\Roaming\Python\Python39\site-packages\FinanceDataReader\krx\listing.py in read(self)
#      18     def read(self):
#      19         url = 'http://data.krx.co.kr/comm/bldAttendant/executeForResourceBundle.cmd?baseName=krx.mdc.i18n.component&key=B128.bld'
# ---> 20         j = json.loads(requests.get(url, headers=self.headers).text)
#      21         date_str = j['result']['output'][0]['max_work_dt']
#      22
#
# c:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     344             parse_int is None and parse_float is None and
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#     348         cls = JSONDecoder
#
# c:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# c:\ProgramData\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
sp_data = fdr.DataReader("005380", "2020-10-01", "2021-09-30")
display(sp_data)
# Out:
#               Open    High     Low   Close   Volume    Change
# Date
# 2020-10-05  183000  187500  181500  187000  2732820  0.047619
# 2020-10-06  188000  188500  181500  182500  2143171 -0.024064
# 2020-10-07  180000  183500  178500  183000  1512423  0.002740
# 2020-10-08  185500  186000  180000  180500  1750474 -0.013661
# 2020-10-12  178000  181500  176000  180000  1655359 -0.002770
# ...            ...     ...     ...     ...      ...       ...
# 2021-09-24  209500  210500  206000  207000   413926 -0.007194
# 2021-09-27  205000  206000  203500  204000   584898 -0.014493
# 2021-09-28  204000  204000  200500  201500   719631 -0.012255
# 2021-09-29  197500  202000  197500  201500   934463  0.000000
# 2021-09-30  200000  201000  199000  200000   594666 -0.007444
#
# [246 rows x 6 columns]

# %%
SP500_stock_list = fdr.StockListing("SP500")
display(SP500_stock_list)
# Out:
#     Symbol                 Name                  Sector  \
# 0      MMM                   3M             Industrials
# 1      AOS          A. O. Smith             Industrials
# 2      ABT  Abbott Laboratories             Health Care
# 3     ABBV               AbbVie             Health Care
# 4      ACN            Accenture  Information Technology
# ..     ...                  ...                     ...
# 498    XYL           Xylem Inc.             Industrials
# 499    YUM          Yum! Brands  Consumer Discretionary
# 500   ZBRA   Zebra Technologies  Information Technology
# 501    ZBH        Zimmer Biomet             Health Care
# 502    ZTS               Zoetis             Health Care
#
#                                          Industry
# 0                        Industrial Conglomerates
# 1                               Building Products
# 2                           Health Care Equipment
# 3                                   Biotechnology
# 4                  IT Consulting & Other Services
# ..                                            ...
# 498  Industrial Machinery & Supplies & Components
# 499                                   Restaurants
# 500            Electronic Equipment & Instruments
# 501                         Health Care Equipment
# 502                               Pharmaceuticals
#
# [503 rows x 4 columns]

# %%
sp_data = fdr.DataReader("MMM", "2020-10-01", "2021-09-30")
display(sp_data)
# Out:
#                   Open        High         Low       Close   Volume  \
# 2020-09-30  134.556854  136.371231  132.617050  133.929764  3656052
# 2020-10-01  134.339462  135.367889  131.872910  132.767563  2378964
# 2020-10-02  130.827759  135.401337  130.643814  134.080261  2115246
# 2020-10-05  135.660538  136.705688  135.250839  136.078598  1742572
# 2020-10-06  136.655518  138.545151  135.309372  135.643814  2418192
# ...                ...         ...         ...         ...      ...
# 2021-09-23  150.627090  152.884613  150.501678  151.780930  2615054
# 2021-09-24  151.755859  152.232437  151.020065  151.371231  2483972
# 2021-09-27  151.195648  153.143814  151.178925  151.998322  2454312
# 2021-09-28  152.023407  152.884613  150.309372  150.543472  2739318
# 2021-09-29  150.434784  151.663879  149.807693  151.237457  2003061
#
#              Adj Close
# 2020-09-30  113.121002
# 2020-10-01  112.139389
# 2020-10-02  113.248116
# 2020-10-05  114.935989
# 2020-10-06  114.568756
# ...                ...
# 2021-09-23  132.335114
# 2021-09-24  131.977921
# 2021-09-27  132.524643
# 2021-09-28  131.256180
# 2021-09-29  131.861267
#
# [252 rows x 6 columns]

# %% [markdown]
# #### 주요 지수 데이터

# %%
import datetime
import pandas as pd

utcnow= datetime.datetime.utcnow()
time_gap= datetime.timedelta(hours=9)
kor_time= utcnow+ time_gap
time_inter=kor_time-pd.DateOffset(years=10)#하루전
start_date = time_inter.strftime("%Y-%m-%d")
kor_end_time = kor_time.strftime(("%Y-%m-%d"))
kor_end_time
# Out:
# '2024-09-12'

# %%
start_date
# Out:
# '2014-09-12'

# %%
KP_idx_data = fdr.DataReader("KS11", "2024-09-11")
display(KP_idx_data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# c:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     970         try:
# --> 971             return complexjson.loads(self.text, **kwargs)
#     972         except JSONDecodeError as e:
#
# c:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     345             parse_constant is None and object_pairs_hook is None and not kw):
# --> 346         return _default_decoder.decode(s)
#     347     if cls is None:
#
# c:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#
# c:\ProgramData\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\FinanceDataReader\krx\data.py in _krx_index_price_2years(idx1, idx2, from_date, to_date)
#      48     try:
# ---> 49         jo = r.json()
#      50     except:
#
# c:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in json(self, **kwargs)
#     974             # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975             raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#     976
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_42236\2532591167.py in <module>
# ----> 1 KP_idx_data = fdr.DataReader("KS11", "2024-09-11")
#       2 display(KP_idx_data)
#
# ~\AppData\Roaming\Python\Python39\site-packages\FinanceDataReader\data.py in DataReader(symbol, start, end, exchange, data_source)
#      65         if symbol in krx_index_symbol_map:
#      66             symbol = krx_index_symbol_map[symbol]
# ---> 67             return KrxIndexReader(symbol, start, end).read()
#      68
#      69         # 1-2) yahoo major indices
#
# ~\AppData\Roaming\Python\Python39\site-packages\FinanceDataReader\krx\data.py in read(self)
#     271     def read(self):
#     272         idx1, idx2 = self.symbol[0], self.symbol[1:]
# --> 273         df = _krx_index_price(idx1, idx2, self.start, self.end)
#     274         df.attrs = {'exchange':'KRX', 'source':'KRX', 'data':'INDEX'}
#     275         return df
#
# ~\AppData\Roaming\Python\Python39\site-packages\FinanceDataReader\krx\data.py in _krx_index_price(idx1, idx2, from_date, to_date)
#      62     _end = datetime(_start.year+2, _start.month, _start.day) - timedelta(days=1)
#      63     while True:
# ---> 64         df = _krx_index_price_2years(idx1, idx2, _start, _end)
#      65         df_list.append(df)
#      66         if to_date <= _end:
#
# ~\AppData\Roaming\Python\Python39\site-packages\FinanceDataReader\krx\data.py in _krx_index_price_2years(idx1, idx2, from_date, to_date)
#      49         jo = r.json()
#      50     except:
# ---> 51         raise ValueError(r.text)
#      52
#      53     return pd.DataFrame(r.json()['output'])
#
# ValueError: <script>
# 				function getIP(){return '10.242.188.55';}
# 				function getURL(){return 'data.krx.co.kr';}
# 				function getCategory(){return 'í¬ìì ë³´';}
# 				function getPolicyName(){return 'ê¸°ë³¸ì ì±';}
# 				function getUserID(){return 'ìë¬´ë§_ì íê³ ë±íêµ';}
# 				function getFullURL(){return 'data.krx.co.kr/comm/bldAttendant/getJsonData.cmd';}
# 				function getOneDepthURL(){return 'data.krx.co.kr/comm/';}
# 				function getKeyword(){return '';}
# 				</script>
# <html><head><meta http-equiv=Content-Type content='text/html; charset=utf-8'></head><body bgcolor=#ffffff><br><br><br><br>
# <CENTER><font face=êµ´ë¦¼ size=4 color=#999900><b>
# <hr color=#0000ff width=80%>
# <FONT color=#000000 size=6>ê²½ê¸°ëêµì¡ì²­ ì ë³´ë³´ì ê¸°ë³¸ì§ì¹¨ì ë°ë¼ í´ë¹ ì¬ì´í¸ë ì ìí  ì ììµëë¤.</font><br><br>
# </b>êµì¡ê³¼ì  ëë ìë¬´ì ì ìì´ íìí ê²½ì° íì±ì¤ì°êµì¡ì§ìì²­ ì ë³´íí(031-371-0728)ì¼ë¡ ë¬¸ìíìê¸° ë°ëëë¤.<br>
# <br>
# <script>document.write (getIP());</script> &nbsp;
# <script>document.write (getURL());</script>&nbsp;&nbsp;*ì°¨ë¨ì¹´íê³ ë¦¬ :
# <script>document.write (getCategory());</script>
# <script>document.write (getPolicyName());</script>
# <hr color=#0000ff width=80%>
# </font></CENTER></BODY></html>

# %%
DJI_idx_data = fdr.DataReader("DJI", "2010-01-01", "2020-12-31")
display(DJI_idx_data)
# Out:
#                     Open          High           Low         Close     Volume  \
# 2009-12-31  10548.509766  10555.009766  10423.129883  10428.049805  137940000
# 2010-01-04  10430.690430  10604.969727  10430.690430  10583.959961  179780000
# 2010-01-05  10584.559570  10584.559570  10522.519531  10572.019531  188540000
# 2010-01-06  10564.719727  10594.990234  10546.549805  10573.679688  186040000
# 2010-01-07  10571.110352  10612.370117  10505.209961  10606.860352  217390000
# ...                  ...           ...           ...           ...        ...
# 2020-12-23  30046.730469  30292.529297  30046.730469  30129.830078  274050000
# 2020-12-24  30155.919922  30209.669922  30099.300781  30199.869141  145570000
# 2020-12-28  30283.230469  30525.560547  30283.230469  30403.970703  302490000
# 2020-12-29  30492.070312  30588.789062  30274.240234  30335.669922  357610000
# 2020-12-30  30415.089844  30525.349609  30393.039062  30409.560547  291890000
#
#                Adj Close
# 2009-12-31  10428.049805
# 2010-01-04  10583.959961
# 2010-01-05  10572.019531
# 2010-01-06  10573.679688
# 2010-01-07  10606.860352
# ...                  ...
# 2020-12-23  30129.830078
# 2020-12-24  30199.869141
# 2020-12-28  30403.970703
# 2020-12-29  30335.669922
# 2020-12-30  30409.560547
#
# [2769 rows x 6 columns]

# %% [markdown]
# ### 기타 금융 데이터 수집

# %%
display(fdr.DataReader("CL", "2020-01-01", "2020-12-31")) # WTI유 선물
# Out:
#                  Open       High        Low      Close   Volume  Adj Close
# 2019-12-31  68.769997  68.919998  68.379997  68.839996  1960200  61.524376
# 2020-01-02  68.839996  68.940002  67.889999  68.120003  3441800  60.880898
# 2020-01-03  67.839996  68.470001  67.680000  68.019997  3473800  60.791512
# 2020-01-06  68.080002  68.849998  68.010002  68.489998  4607500  61.211578
# 2020-01-07  68.459999  68.459999  67.470001  67.550003  4500000  60.371460
# ...               ...        ...        ...        ...      ...        ...
# 2020-12-23  84.589996  84.959999  84.199997  84.430000  2690400  77.251572
# 2020-12-24  84.620003  85.099998  84.489998  85.040001   733200  77.809692
# 2020-12-28  85.279999  85.680000  84.980003  85.410004  1225800  78.148239
# 2020-12-29  85.830002  86.209999  84.919998  85.029999  2390900  77.800552
# 2020-12-30  85.180000  85.339996  84.550003  84.730003  2158000  77.526070
#
# [253 rows x 6 columns]

# %%
display(fdr.DataReader("USD/KRW", "2020-01-01", "2020-12-31")) #달러/원 환율
# Out:
#                    Open         High          Low        Close  Volume  \
# 2019-12-31  1156.339966  1158.189941  1151.739990  1156.349976       0
# 2020-01-01  1154.400024  1154.400024  1145.449951  1153.750000       0
# 2020-01-02  1153.959961  1160.189941  1145.199951  1153.969971       0
# 2020-01-03  1157.550049  1168.069946  1155.310059  1157.150024       0
# 2020-01-06  1167.400024  1172.489990  1165.640015  1165.849976       0
# ...                 ...          ...          ...          ...     ...
# 2020-12-24  1105.000000  1105.939941  1099.359985  1104.800049       0
# 2020-12-25  1098.900024  1101.660034  1098.900024  1099.910034       0
# 2020-12-28  1099.089966  1106.000000  1093.300049  1099.089966       0
# 2020-12-29  1096.420044  1096.420044  1089.969971  1095.000000       0
# 2020-12-30  1091.250000  1092.469971  1083.650024  1092.619995       0
#
#               Adj Close
# 2019-12-31  1156.349976
# 2020-01-01  1153.750000
# 2020-01-02  1153.969971
# 2020-01-03  1157.150024
# 2020-01-06  1165.849976
# ...                 ...
# 2020-12-24  1104.800049
# 2020-12-25  1099.910034
# 2020-12-28  1099.089966
# 2020-12-29  1095.000000
# 2020-12-30  1092.619995
#
# [262 rows x 6 columns]

# %%
display(fdr.DataReader("KR10YT=RR", "2020-01-01", "2020-12-31")) # 10년만기 한국 국채
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_42236\3329158675.py in <module>
# ----> 1 display(fdr.DataReader("KR10YT=RR", "2020-01-01", "2020-12-31")) # 10년만기 한국 국채
#
# ~\AppData\Roaming\Python\Python39\site-packages\FinanceDataReader\data.py in DataReader(symbol, start, end, exchange, data_source)
#      90         else:
#      91             # Yahoo is default source for US and other stocks
# ---> 92             return YahooDailyReader(codes, start, end).read()
#      93
#      94     else:  # data source specified
#
# ~\AppData\Roaming\Python\Python39\site-packages\FinanceDataReader\yahoo\data.py in read(self)
#      59         # single symbol
#      60         if ',' not in self.symbol:
# ---> 61             return _yahoo_data_reader(self.symbol, self.exchange, self.start, self.end)
#      62
#      63         # multiple symbols, merge close price data as columns
#
# ~\AppData\Roaming\Python\Python39\site-packages\FinanceDataReader\yahoo\data.py in _yahoo_data_reader(symbol, exchange, start, end)
#      36     )
#      37     r = requests.get(url, headers={'user-agent': 'Mozilla/5.0 AppleWebKit/537.36'})
# ---> 38     r.raise_for_status()
#      39     jo = r.json()
#      40
#
# c:\ProgramData\Anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#    1019
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#    1023     def close(self):
#
# HTTPError: 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v8/finance/chart/KR10YT=RR?period1=1577804400&period2=1609340400&interval=1d&includeAdjustedClose=true
