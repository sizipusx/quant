# %%
import OpenDartReader

# %% [markdown]
# ### 객체 생성

# %%
import OpenDartReader # 모듈 불러오기
my_api = "c63219e7d4e8fd758c00021fb6bf6ec64d23d312" # API KEY 지정 
dart = OpenDartReader(my_api) # OpenDartReader 객체 생성하기

# %% [markdown]
# ### 주요 메서드

# %% [markdown]
# #### list 메서드

# %%
result = dart.list("삼성전자", start = "2020-01-01", end = "2024-06-30")
display(result.tail()) # 위 5개 행 출력
display(result.shape) # 데이터프레임 구조 출력
# Out:
#     corp_code corp_name stock_code corp_cls            report_nm  \
# 916  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 917  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 918  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 919  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
# 920  00126380      삼성전자     005930        Y  임원ㆍ주요주주특정증권등소유상황보고서
#
#            rcept_no  flr_nm  rcept_dt rm
# 916  20200107000126  국민연금공단  20200107
# 917  20200103000451     조승환  20200103
# 918  20200103000166     안규리  20200103
# 919  20200102000241     엄대현  20200102
# 920  20200102000022     이태협  20200102
# (921, 9)

# %% [markdown]
# #### document 메서드

# %%
doc = dart.document("20200103000166")
print(doc)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
#
#
# <DOCUMENT xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:noNamespaceSchemaLocation="dart3.xsd">
#
# <DOCUMENT-HEADER AEXT-CLASS="Y">
# <DOCUMENT-NAME ACODE="00634">임원ㆍ주요주주 특정증권등 소유상황보고서</DOCUMENT-NAME>
# <FORMULA-VERSION ADATE="20190115">4.0</FORMULA-VERSION>
# <COMPANY-NAME AREGCIK="00126380">삼성전자</COMPANY-NAME>
#
# <SUMMARY>
# <EXTRACTION ACODE="OUTDATE" AFEATURE="BOTH">20191230</EXTRACTION>
# </SUMMARY>
# </DOCUMENT-HEADER>
#
# <BODY>
#
# <INSERTION ABASISNUMBER="SE1" AFREQUENCY="0" ADUPLICATION="N">
# <COMMENT>◆click◆ 정정문서 작성시 『정오표』 삽입</COMMENT>
# <LIBRARYLIST>정정신고(보고).LCommon</LIBRARYLIST>
# </INSERTION>
#
# <COVER>
# <P></P>
# <COVER-TITLE ATOC="Y" AASSOCNOTE="COVER">임원ㆍ주요주주 특정증권등 소유상황보고서</COVER-TITLE>
# <P></P>
#
# <TABLE-GROUP ACLASS="RPT_RSP_DT" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="600" BORDER="0">
#
# <COLGROUP>
# <COL WIDTH="251"></COL>
# <COL WIDTH="154"></COL>
# <COL WIDTH="168"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="260" HEIGHT="30">증권선물위원회 귀중</TD>
# <TD WIDTH="163" HEIGHT="30"></TD>
# <TD ALIGN="CENTER" WIDTH="177" HEIGHT="30"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="260" HEIGHT="30">한국거래소 귀중</TD>
# <TD WIDTH="163" HEIGHT="30"></TD>
# <TD ALIGN="CENTER" WIDTH="177" HEIGHT="30"></TD>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ROWSPAN="2" WIDTH="260" HEIGHT="60"></TD>
# <TD WIDTH="163" HEIGHT="30" AUPDATECONT="N">보고의무발생일   :</TD>
# <TU ALIGN="CENTER" WIDTH="177" HEIGHT="30" AUNIT="RPT_RSP_DT" AUNITVALUE="20191230">2019년 12월 30일</TU>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="163" HEIGHT="30" AUPDATECONT="N">보고서작성기준일 : </TD>
# <TU ALIGN="CENTER" WIDTH="177" HEIGHT="30" AUNIT="RPT_REF_DT" AUNITVALUE="20200103">2020년 01월 03일</TU>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
# <P></P>
#
# <TABLE ACLASS="NORMAL" AFIXTABLE="Y" WIDTH="600" BORDER="1">
#
# <COLGROUP>
# <COL WIDTH="591"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD WIDTH="600" HEIGHT="76" AUPDATECONT="N">※ 보고자 본인은 보고서작성기준일 현재 본인의 특정증권등의 소유상황을 관련 법규 및 기재상의 주의에 따라 정확하게 작성하였고, 중요한 사항의 허위기재 또는 기재누락이 없음을 확인합니다.</TD>
# </TR>
# </TBODY>
# </TABLE>
# <P></P>
#
# <TABLE ACLASS="NORMAL" AFIXTABLE="N" WIDTH="600" BORDER="0">
#
# <COLGROUP>
# <COL WIDTH="160"></COL>
# <COL WIDTH="422"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="169" HEIGHT="30">보고자 :</TD>
# <TD VALIGN="MIDDLE" WIDTH="431" HEIGHT="30">안 규 리</TD>
# </TR>
# </TBODY>
# </TABLE>
# <P></P>
# <P></P>
# <PGBRK></PGBRK>
# <P></P>
# </COVER>
#
# <SECTION-1 ACLASS="MANDATORY" APARTSOURCE="SOURCE">
#
# <SECTION-2 ACLASS="MANDATORY">
# <TITLE ATOC="Y" AASSOCNOTE="D-0-1-1-0">1. 발행회사에 관한 사항</TITLE>
#
# <TABLE-GROUP ACLASS="CRP_NM" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="600" BORDER="1">
#
# <COLGROUP>
# <COL WIDTH="141"></COL>
# <COL WIDTH="128"></COL>
# <COL WIDTH="154"></COL>
# <COL WIDTH="141"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="150" HEIGHT="30" AUPDATECONT="N">회 사 명</TD>
# <TE VALIGN="MIDDLE" WIDTH="450" HEIGHT="30" ACODE="CRP_NM" COLSPAN="3">삼성전자</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="150" HEIGHT="30" AUPDATECONT="N">법인구분</TD>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="137" HEIGHT="30" AUNIT="CRP_DST" AUNITVALUE="1">유가증권상장법인</TU>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="163" HEIGHT="30" AUPDATECONT="N">회사코드 </TD>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="150" HEIGHT="30" ACODE="CRP_CD">005930</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="150" HEIGHT="30" AUPDATECONT="N">발행주식 총수</TD>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="450" HEIGHT="30" ACODE="FLT_SUM" COLSPAN="3">6,792,669,250</TE>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
# <P></P>
# </SECTION-2>
#
# <SECTION-2 ACLASS="MANDATORY">
# <TITLE ATOC="Y" AASSOCNOTE="D-0-1-2-0">2. 보고자에 관한 사항</TITLE>
#
# <INSERTION ABASISNUMBER="E0" AFREQUENCY="0" ADUPLICATION="N">
# <COMMENT>보고자가 개인인 경우 「생년월일 또는 사업자등록번호등」란에는 생년월일만 연ㆍ월ㆍ일 순으로 6자리 숫자(예: 2005년 6월 1일생인 자의 경우 050601)를 기재하고 주민등록번호는 기재하지 않도록 유의하며, 「주소」란에는 행정구역상의 읍ㆍ면ㆍ동까지만 기재함.(<= 이 문구는 인쇄되지 않음)</COMMENT>
# <LIBRARYLIST></LIBRARYLIST>
# </INSERTION>
#
# <TABLE-GROUP ACLASS="IFR_NM" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="600" BORDER="1">
#
# <COLGROUP>
# <COL WIDTH="124"></COL>
# <COL WIDTH="106"></COL>
# <COL WIDTH="118"></COL>
# <COL WIDTH="80"></COL>
# <COL WIDTH="127"></COL>
# </COLGROUP>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="133" HEIGHT="30" AUPDATECONT="N">보고구분</TD>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="115" HEIGHT="30" AUNIT="RPT_DST" AUNITVALUE="2">변동</TU>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="127" HEIGHT="30" AUPDATECONT="N">보고자 구분</TD>
# <TU COLSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="225" HEIGHT="30" AUNIT="IFR_TP" AUNITVALUE="D">개인(국내)</TU>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="133" HEIGHT="83" AUPDATECONT="N">성명(명칭)</TD>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="115" HEIGHT="53" AUPDATECONT="N">한     글</TD>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="127" HEIGHT="53" ACODE="IFR_NM">안규리</TE>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="89" HEIGHT="53" AUPDATECONT="N">한자(영문)</TD>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="136" HEIGHT="53" ACODE="IFR_NM_HJ">安圭里&cr;(Ahn, Curie)</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD COLSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="242" HEIGHT="30" AUPDATECONT="N">생년월일 또는 사업자등록번호 등</TD>
# <TE COLSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="225" HEIGHT="30" ACODE="IFR_ID2">550317</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="133" HEIGHT="76" AUPDATECONT="N">주소(본점소재지)&cr;[읍ㆍ면ㆍ동까지만 기재]</TD>
# <TE COLSPAN="4" VALIGN="MIDDLE" WIDTH="467" HEIGHT="76" ACODE="IFR_ADR2">서울시 성북구 길음동</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ROWSPAN="3" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="133" HEIGHT="113" AUPDATECONT="N">발행회사와의 관계</TD>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="115" HEIGHT="30" AUPDATECONT="N">임원(등기여부)</TD>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="127" HEIGHT="30" AUNIT="STF_RYN" AUNITVALUE="Y">등기임원</TU>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="89" HEIGHT="30" AUPDATECONT="N">직위명</TD>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="136" HEIGHT="30" ACODE="STF_PSM">사외이사</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="115" HEIGHT="53" AUPDATECONT="N">선임일</TD>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="127" HEIGHT="53" AUNIT="STF_APT_DT" AUNITVALUE="20190320">2019년 03월 20일</TU>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="89" HEIGHT="53" AUPDATECONT="N">퇴임일</TD>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="136" HEIGHT="53" AUNIT="STF_RET_DT" AUNITVALUE="-">-</TU>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="115" HEIGHT="30" AUPDATECONT="N">주요주주</TD>
# <TU COLSPAN="3" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="352" HEIGHT="30" AUNIT="MAIN_SH" AUNITVALUE="4">-</TU>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ROWSPAN="4" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="133" HEIGHT="120" AUPDATECONT="N">업무상 연락처&cr;및 담당자</TD>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="115" HEIGHT="30" AUPDATECONT="N">소속회사</TD>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="127" HEIGHT="30" ACODE="RSP_MAN_DPT">삼성전자</TE>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="89" HEIGHT="30" AUPDATECONT="N">부      서</TD>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="136" HEIGHT="30" ACODE="RSP_MAN_DPT2">인사팀</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="115" HEIGHT="30" AUPDATECONT="N">직      위</TD>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="127" HEIGHT="30" ACODE="RSP_MAN_PST">CL3</TE>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="89" HEIGHT="30" AUPDATECONT="N">전화번호</TD>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="136" HEIGHT="30" ACODE="RSP_MAN_PHN2">031-27******</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="115" HEIGHT="30" AUPDATECONT="N">성      명</TD>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="127" HEIGHT="30" ACODE="RSP_MAN">홍영택</TE>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="89" HEIGHT="30" AUPDATECONT="N">팩스번호</TD>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="136" HEIGHT="30" ACODE="RSP_MAN_FAX">031-27******</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="115" HEIGHT="30" AUPDATECONT="N">이메일 주소</TD>
# <TE COLSPAN="3" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="352" HEIGHT="30" ACODE="RSP_MAN_EML">**********9.hong@samsung.com</TE>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
#
# <INSERTION ABASISNUMBER="E0" AFREQUENCY="0" ADUPLICATION="N">
# <COMMENT>※ 주식등의 대량보유상황보고와 임원ㆍ주요주주 소유상황보고는 요건 및 면제사유 등이 상이하므로 보고시 주의 (이 문구는 인쇄되지 않음)&cr; 1.주식등의 대량보유상황보고 면제사유(하단 기재상의 주의사항의 링크 참조)&cr; 2.임원ㆍ주요주주 소유상황보고 면제사유(하단 기재상의 주의사항의 링크 참조)&cr; 3.양자의 공시요건 및 면제사유 등 차이점 비교표(하단 기재상의 주의사항의 링크 참조)</COMMENT>
# <LIBRARYLIST></LIBRARYLIST>
# </INSERTION>
# <P></P>
# </SECTION-2>
#
# <SECTION-2 ACLASS="MANDATORY">
# <TITLE ATOC="Y">3. 특정증권등의 소유상황</TITLE>
#
# <SECTION-3 ACLASS="MANDATORY">
# <TITLE ATOC="Y" AASSOCNOTE="D-0-1-3-1">가. 소유 특정증권등의 수 및 소유비율</TITLE>
#
# <TABLE-GROUP ACLASS="BFR_PS_CNT" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="590" BORDER="1">
#
# <COLGROUP>
# <COL WIDTH="81"></COL>
# <COL WIDTH="118"></COL>
# <COL WIDTH="117"></COL>
# <COL WIDTH="61"></COL>
# <COL WIDTH="102"></COL>
# <COL WIDTH="57"></COL>
# </COLGROUP>
#
# <THEAD>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="90" HEIGHT="83" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" AUPDATECONT="N"></TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="127" HEIGHT="83" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" AUPDATECONT="N">보고서&cr;작성 기준일</TH>
# <TH COLSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="196" HEIGHT="30" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" AUPDATECONT="N">특정증권등</TH>
# <TH COLSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="177" HEIGHT="30" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" AUPDATECONT="N">주권</TH>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="126" HEIGHT="53" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" AUPDATECONT="N">특정증권등의&cr;수(주)</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="70" HEIGHT="53" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" AUPDATECONT="N">비율(%)</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="111" HEIGHT="53" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" AUPDATECONT="N">주식수(주)</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="66" HEIGHT="53" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" AUPDATECONT="N">비율(%)</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="90" HEIGHT="53" AUPDATECONT="N">직전보고서</TD>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="127" HEIGHT="53" AUNIT="BFR_RPT_DT" AUNITVALUE="20191205">2019년 12월 05일</TU>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="126" HEIGHT="53" ACODE="BFR_UN_CNT">700</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="70" HEIGHT="53" ACODE="BFR_UN_RT">0.00</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="111" HEIGHT="53" ACODE="BFR_PS_CPT_CNT">700</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="66" HEIGHT="53" ACODE="BFR_PS_CPT_RT">0.00</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="90" HEIGHT="53" AUPDATECONT="N">이번보고서</TD>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="127" HEIGHT="53" AUNIT="AFR_RPT_DT" AUNITVALUE="20200103">2020년 01월 03일</TU>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="126" HEIGHT="53" ACODE="AFR_UN_CNT">800</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="70" HEIGHT="53" ACODE="AFR_UN_RT">0.00</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="111" HEIGHT="53" ACODE="AFR_PS_CPT_CNT">800</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="66" HEIGHT="53" ACODE="AFR_PS_CPT_RT">0.00</TE>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TD COLSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="217" HEIGHT="30" AUPDATECONT="N">증     감</TD>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="126" HEIGHT="30" ACODE="MDF_UN_CNT">100</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="70" HEIGHT="30" ACODE="MDF_UN_RT">0.00</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="111" HEIGHT="30" ACODE="MDF_PS_CPT_CNT">100</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="66" HEIGHT="30" ACODE="MDF_PS_CPT_RT">0.00</TE>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
# <P></P>
# </SECTION-3>
#
# <SECTION-3 ACLASS="MANDATORY">
# <TITLE ATOC="Y" AASSOCNOTE="D-0-1-3-2">나. 특정증권등의 종류별 소유내역</TITLE>
#
# <TABLE-GROUP ACLASS="CST_CNT1" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="N" WIDTH="714" BORDER="1">
#
# <COLGROUP>
# <COL WIDTH="124"></COL>
# <COL WIDTH="66"></COL>
# <COL WIDTH="51"></COL>
# <COL WIDTH="65"></COL>
# <COL WIDTH="77"></COL>
# <COL WIDTH="51"></COL>
# <COL WIDTH="43"></COL>
# <COL WIDTH="35"></COL>
# <COL WIDTH="56"></COL>
# <COL WIDTH="56"></COL>
# </COLGROUP>
#
# <THEAD>
#
# <TR ACOPY="N" ADELETE="N">
# <TH COLSPAN="10" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="714" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">특정증권등의 내역</TH>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="133" HEIGHT="83" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N" ROWSPAN="2">주 권</TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="75" HEIGHT="83" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">신주&cr;인수권이&cr;표시된것</TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="60" HEIGHT="83" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">전환&cr;사채권</TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="74" HEIGHT="83" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">신주&cr;인수권부&cr;사채권</TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="86" HEIGHT="83" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">이익참가부&cr;사채권</TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="60" HEIGHT="83" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">교환&cr;사채권</TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="52" HEIGHT="83" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">증권&cr;예탁&cr;증권</TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="44" HEIGHT="83" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">기타</TH>
# <TH COLSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="130" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">합 계</TH>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="65" HEIGHT="53" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">주수&cr;(주)</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="65" HEIGHT="53" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">비율&cr;(%)</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="N" ADELETE="N">
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="133" HEIGHT="30" ACODE="CPT_CNT">800</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="75" HEIGHT="30" ACODE="ACC_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="60" HEIGHT="30" ACODE="CB_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="74" HEIGHT="30" ACODE="LN_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="86" HEIGHT="30" ACODE="BN_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="60" HEIGHT="30" ACODE="EB_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="52" HEIGHT="30" ACODE="CF_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="44" HEIGHT="30" ACODE="ET_CNT">-</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="65" HEIGHT="30" ACODE="STK_CNT">800</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="65" HEIGHT="30" ACODE="STK_RT">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="133" HEIGHT="60" AUPDATECONT="N" ROWSPAN="2">A</TD>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="75" HEIGHT="30" AUPDATECONT="N">B</TD>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="60" HEIGHT="30" AUPDATECONT="N">C</TD>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="74" HEIGHT="30" AUPDATECONT="N">D</TD>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="86" HEIGHT="30" AUPDATECONT="N">E</TD>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="60" HEIGHT="30" AUPDATECONT="N">F</TD>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="52" HEIGHT="30" AUPDATECONT="N">G</TD>
# <TD ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="44" HEIGHT="30" AUPDATECONT="N">H</TD>
# <TD ROWSPAN="2" ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="65" HEIGHT="60" AUPDATECONT="N"></TD>
# <TD ROWSPAN="2" ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="65" HEIGHT="60" AUPDATECONT="N"></TD>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD COLSPAN="7" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="451" HEIGHT="30" AUPDATECONT="N">I</TD>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
# <P></P>
#
# <TABLE-GROUP ACLASS="HLD_RT" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="Y" WIDTH="600" BORDER="1">
#
# <COLGROUP>
# <COL WIDTH="109"></COL>
# <COL WIDTH="160"></COL>
# <COL WIDTH="156"></COL>
# <COL WIDTH="139"></COL>
# </COLGROUP>
#
# <THEAD>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="118" HEIGHT="106" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" AUPDATECONT="N">발행주식 총수&cr;(J)</TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="169" HEIGHT="106" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" AUPDATECONT="N">주식외 특정증권등의 수&cr;(B+C+D+E+F+G+H=I)</TH>
# <TH COLSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="313" HEIGHT="30" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" AUPDATECONT="N">소유비율(%)</TH>
# </TR>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="165" HEIGHT="76" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" AUPDATECONT="N">특정증권등의 소유비율&cr;[A+I / J+I-(F+G+H)※] × 100</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="148" HEIGHT="76" ACOPYCOL="Y" ADELETECOL="Y" AMOVECOL="N" AUPDATECONT="N">주권의 소유비율&cr;(A / J) × 100</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="Y">
# <TE ALIGN="RIGHT" WIDTH="118" HEIGHT="30" ACODE="VOT_STK_CNT">6,792,669,250</TE>
# <TE ALIGN="RIGHT" WIDTH="169" HEIGHT="30" ACODE="HLD_STK_CNT">0</TE>
# <TE ALIGN="RIGHT" WIDTH="165" HEIGHT="30" ACODE="HLD_STK_RT">0.00</TE>
# <TE ALIGN="RIGHT" WIDTH="148" HEIGHT="30" ACODE="HLD_CMT_RT">0.00</TE>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
# <P>※ 교환대상이 주식인 교환사채권 및 기초자산이 주식인 증권예탁증권, 파생결합증권 등에 한하여 분모에서 제외하고 소유비율을 산정&cr;</P>
# </SECTION-3>
#
# <SECTION-3 ACLASS="MANDATORY">
# <TITLE ATOC="Y" AASSOCNOTE="D-0-1-3-3">다. 세부변동내역</TITLE>
#
# <TABLE-GROUP ACLASS="RPT_RSN" ADELETETABLE="N">
#
# <TABLE ACLASS="EXTRACTION" AFIXTABLE="N" WIDTH="710" BORDER="1">
#
# <COLGROUP>
# <COL WIDTH="66"></COL>
# <COL WIDTH="103"></COL>
# <COL WIDTH="106"></COL>
# <COL WIDTH="65"></COL>
# <COL WIDTH="64"></COL>
# <COL WIDTH="64"></COL>
# <COL WIDTH="112"></COL>
# <COL WIDTH="58"></COL>
# </COLGROUP>
#
# <THEAD>
#
# <TR ACOPY="N" ADELETE="N">
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="75" HEIGHT="60" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">보고사유</TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="112" HEIGHT="60" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">변동일*</TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="115" HEIGHT="60" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">특정증권등의&cr;종류</TH>
# <TH COLSPAN="3" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="220" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">소 유 주 식 수 (주)</TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="121" HEIGHT="60" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">취득/처분&cr;단가(원)**</TH>
# <TH ROWSPAN="2" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="67" HEIGHT="60" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">비 고</TH>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="74" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">변동전</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="73" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">증감</TH>
# <TH ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="73" HEIGHT="30" ACOPYCOL="N" ADELETECOL="N" AMOVECOL="N" AUPDATECONT="N">변동후</TH>
# </TR>
# </THEAD>
#
# <TBODY>
#
# <TR ACOPY="Y" ADELETE="N">
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="75" HEIGHT="53" AUNIT="RPT_RSN" AUNITVALUE="01">장내매수(+)</TU>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="112" HEIGHT="53" AUNIT="MDF_DM" AUNITVALUE="20191230">2019년 12월 30일</TU>
# <TU ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="115" HEIGHT="53" AUNIT="STR_KND" AUNITVALUE="1">보통주</TU>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="74" HEIGHT="53" ACODE="BFR_STK_CNT">700</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="73" HEIGHT="53" ACODE="MDF_STK_CNT">100</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="73" HEIGHT="53" ACODE="AFR_STK_CNT">800</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="121" HEIGHT="53" ACODE="ACI_AMT2">54,900</TE>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="67" HEIGHT="53" ACODE="RMK">-</TE>
# </TR>
#
# <TR ACOPY="N" ADELETE="N">
# <TD COLSPAN="3" ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="302" HEIGHT="30" AUPDATECONT="N">합  계</TD>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="74" HEIGHT="30" ACODE="BFR_STK_SUM">700</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="73" HEIGHT="30" ACODE="MDF_STK_SUM">100</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="73" HEIGHT="30" ACODE="AFR_STK_SUM">800</TE>
# <TE ALIGN="RIGHT" VALIGN="MIDDLE" WIDTH="121" HEIGHT="30" ACODE="ACI_AMT_SUM2">54,900</TE>
# <TE ALIGN="CENTER" VALIGN="MIDDLE" WIDTH="67" HEIGHT="30" ACODE="SUM_RMK">-</TE>
# </TR>
# </TBODY>
# </TABLE>
# </TABLE-GROUP>
# <P>*   증권시장에서 주식등을 매매한 경우에는 그 결제일</P>
# <P>** 주식 외의 증권의 경우 해당 증권의 행사(전환ㆍ교환)가액 또는 해당 증권의 권리행사로 취득ㆍ처분하는 주식의 매매단가를 의미하며, (   )의 금액은 해당 증권의 매매단가를 의미</P>
#
# <INSERTION ABASISNUMBER="E0" AFREQUENCY="0" ADUPLICATION="N">
# <COMMENT>※ 주권상장법인의 임.직원 또는 주요주주로서 그 법인의 특정증권등을 6개월 이내에 매수후 매도하거나 매도후 매수하여 이익이 발생한 경우에 내부정보 이용 여부를 불문하고 당해 법인이 동 차익에 대해 반환청구(단기매매차익 반환)를 할 수 있으므로 주의(이 문구는 인쇄되지 않음) 1.단기매매차익 반환제도 안내(하단 기재상의 주의사항의 링크 참조)&cr; 2.단기매매차익 산정방법(하단 기재상의 주의사항의 링크 참조)&cr; 3.주요 단기매매차익 반환사례(하단 기재상의 주의사항의 링크 참조)</COMMENT>
# <LIBRARYLIST></LIBRARYLIST>
# </INSERTION>
# <P></P>
# </SECTION-3>
# </SECTION-2>
# </SECTION-1>
# </BODY>
# </DOCUMENT>

# %% [markdown]
# #### company 메서드

# %%
print(dart.company("현대자동차"))
# Out:
# {'status': '000', 'message': '정상', 'corp_code': '00164742', 'corp_name': '현대자동차(주)', 'corp_name_eng': 'HYUNDAI MOTOR CO', 'stock_name': '현대자동차', 'stock_code': '005380', 'ceo_nm': '정의선, 장재훈, 이동석(각자 대표이사)', 'corp_cls': 'Y', 'jurir_no': '1101110085450', 'bizr_no': '1018109147', 'adres': '서울특별시 서초구  헌릉로 12', 'hm_url': 'www.hyundai.com', 'ir_url': '', 'phn_no': '02-3464-1114', 'fax_no': '02-3464-8719', 'induty_code': '30121', 'est_dt': '19671229', 'acc_mt': '12'}

# %% [markdown]
# #### report 메서드

# %%
display(dart.report("SK하이닉스", "배당", 2023, "11011"))
# Out:
#           rcept_no corp_cls corp_code corp_name              se      thstrm  \
# 0   20240319000684        Y  00164779    SK하이닉스       주당액면가액(원)       5,000
# 1   20240319000684        Y  00164779    SK하이닉스  (연결)당기순이익(백만원)  -9,112,428
# 2   20240319000684        Y  00164779    SK하이닉스  (별도)당기순이익(백만원)  -4,836,170
# 3   20240319000684        Y  00164779    SK하이닉스    (연결)주당순이익(원)     -13,244
# 4   20240319000684        Y  00164779    SK하이닉스    현금배당금총액(백만원)     825,721
# 5   20240319000684        Y  00164779    SK하이닉스    주식배당금총액(백만원)           -
# 6   20240319000684        Y  00164779    SK하이닉스   (연결)현금배당성향(%)           -
# 7   20240319000684        Y  00164779    SK하이닉스      현금배당수익률(%)        0.90
# 8   20240319000684        Y  00164779    SK하이닉스      현금배당수익률(%)           -
# 9   20240319000684        Y  00164779    SK하이닉스      주식배당수익률(%)           -
# 10  20240319000684        Y  00164779    SK하이닉스      주식배당수익률(%)           -
# 11  20240319000684        Y  00164779    SK하이닉스     주당 현금배당금(원)       1,200
# 12  20240319000684        Y  00164779    SK하이닉스     주당 현금배당금(원)           -
# 13  20240319000684        Y  00164779    SK하이닉스      주당 주식배당(주)           -
# 14  20240319000684        Y  00164779    SK하이닉스      주당 주식배당(주)           -
#
#        frmtrm       lwfr stock_knd
# 0       5,000      5,000       NaN
# 1   2,229,560  9,602,316       NaN
# 2   2,790,457  9,567,226       NaN
# 3       3,242     13,989       NaN
# 4     825,181  1,058,936       NaN
# 5           -          -       NaN
# 6       37.00      11.00       NaN
# 7        1.50       1.20       보통주
# 8           -          -       우선주
# 9           -          -       보통주
# 10          -          -       우선주
# 11      1,200      1,540       보통주
# 12          -          -       우선주
# 13          -          -       보통주
# 14          -          -       우선주

# %% [markdown]
# #### finstate 메서드

# %%
result = dart.finstate("LG전자", 2020, "11011") 
result = result.loc[result["fs_nm"] == "연결재무제표"] 
result = result.loc[result["account_nm"].isin(["당기순이익", "영업이익", "매출액"])] 
result = result.loc[:, ["account_nm", "fs_nm", "sj_nm", "thstrm_dt", "thstrm_amount"]]
display(result)
# Out:
#    account_nm   fs_nm  sj_nm                thstrm_dt       thstrm_amount
# 9         매출액  연결재무제표  손익계산서  2020.01.01 ~ 2020.12.31  63,262,046,000,000
# 10       영업이익  연결재무제표  손익계산서  2020.01.01 ~ 2020.12.31   3,194,987,000,000
# 12      당기순이익  연결재무제표  손익계산서  2020.01.01 ~ 2020.12.31   2,063,790,000,000

# %%
print(result["thstrm_amount"].dtype) # 데이터 타입 확인
# Out:
# object

# %%
def remove_comma(value):
    return float(value.replace(",", ""))

display(result["thstrm_amount"].apply(remove_comma))
display(result["thstrm_amount"].str.replace(",", "").astype(float))
# Out:
# 9     6.326205e+13
# 10    3.194987e+12
# 12    2.063790e+12
# Name: thstrm_amount, dtype: float64
# 9     6.326205e+13
# 10    3.194987e+12
# 12    2.063790e+12
# Name: thstrm_amount, dtype: float64
